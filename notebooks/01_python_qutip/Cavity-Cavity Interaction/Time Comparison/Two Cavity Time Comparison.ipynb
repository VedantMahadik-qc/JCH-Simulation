# %%
import matplotlib.pyplot as plt
    
N_list = [3, 5, 8, 10, 12, 15, 18, 20]
python_times = [0.0022302, 0.0030699, 0.0030446, 0.0050006, 0.0049982, 0.0069997, 0.0079985, 0.0090005]
julia_times  = [0.0002325, 0.0002602, 0.0004346, 0.0007712, 0.0008581, 0.0012259, 0.0013819, 0.0018227]

plt.figure(figsize=(8, 5))
plt.plot(N_list, python_times, 'o-', label='Python (QuTiP)', color='blue')
plt.plot(N_list, julia_times, 's-', label='Julia (QuantumOptics.jl)', color='red')
plt.xlabel('Hilbert Space Cutoff (N)')
plt.ylabel('Execution Time (seconds)')
plt.title('Performance Comparison: 2-Site JCH Model')
plt.legend()
plt.yscale('log')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

N_list = [3, 5, 8, 10, 12, 15, 18, 20]

# Paste your results here:
python_qutip_times = [0.0022302, 0.0030699, 0.0030446, 0.0050006, 0.0049982, 0.0069997, 0.0079985, 0.0090005]
julia_qopt_times   = [0.0002325, 0.0002602, 0.0004346, 0.0007712, 0.0008581, 0.0012259, 0.0013819, 0.0018227]
julia_qtool_times  = [0.0013074, 0.0006501, 0.0009523, 0.0014473, 0.0027725, 0.0030302, 0.004251, 0.003961]

plt.figure(figsize=(10, 6))

plt.plot(N_list, python_qutip_times, 'o-', label='Python (QuTiP)', color='blue', linewidth=2)
plt.plot(N_list, julia_qopt_times, 's-', label='Julia (QuantumOptics.jl)', color='red', linewidth=2)
plt.plot(N_list, julia_qtool_times, '^-', label='Julia (QuantumToolbox.jl)', color='green', linewidth=2)

plt.xlabel('Hilbert Space Cutoff (N)', fontsize=12)
plt.ylabel('Execution Time (seconds)', fontsize=12)
plt.title('Simulation Speed: QuTiP vs. Julia Ecosystem', fontsize=14)
plt.legend(fontsize=11)
plt.yscale('log') # Log scale helps see orders of magnitude differences
plt.grid(True, which="both", ls="--", alpha=0.5)
plt.tight_layout()
plt.show()
